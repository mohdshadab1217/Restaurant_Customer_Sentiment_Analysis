# %% [markdown]
# ### Training a model with sklearn for restorent customer sentiment anaylysis (label 1 means rating 4 or 5 and label 0 means rating 1 or 2)

# %%
import pandas as pd

# %%
df=pd.read_csv('datasets/Reviews.csv',usecols=['Summary','Score'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Score    568454 non-null  int64
#  1   Summary  568427 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 8.7+ MB

# %%
df.dropna(how='any',inplace=True)

# %%
df=df[df.Score!=3]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 525789 entries, 0 to 568453
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Score    525789 non-null  int64
#  1   Summary  525789 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 12.0+ MB

# %%
df0=df[(df.Score ==1) | (df.Score==2)].sample(1000, random_state=1)

df1=df[(df.Score==4) | (df.Score==5)].sample(1000,random_state=1)

df=pd.concat([df0,df1])

# %%
df
# Out:
#         Score                                            Summary
# 230527      2                                               WEAK
# 117836      1                           too much of a good thing
# 235676      1                 The most taste-less Earl Grey ever
# 390337      1                                  very disappointed
# 402857      1  Changed the ingredients to now include meat pr...
# ...       ...                                                ...
# 333485      5                                       Great Stuff!
# 542541      5                                Almost good as real
# 261703      5                 IMO, the perfect canned beef frank
# 517281      5                                       great taste!
# 341234      5                                           Popchips
#
# [2000 rows x 2 columns]

# %%
# Labeling data with 0 and 1 
for i,j in enumerate(df.Score):
    if j ==4 or j==5:
        df.iloc[i,0]=1 
    elif j==1 or j==2:
        df.iloc[i,0]=0

# %%
df
# Out:
#         Score                                            Summary
# 230527      0                                               WEAK
# 117836      0                           too much of a good thing
# 235676      0                 The most taste-less Earl Grey ever
# 390337      0                                  very disappointed
# 402857      0  Changed the ingredients to now include meat pr...
# ...       ...                                                ...
# 333485      1                                       Great Stuff!
# 542541      1                                Almost good as real
# 261703      1                 IMO, the perfect canned beef frank
# 517281      1                                       great taste!
# 341234      1                                           Popchips
#
# [2000 rows x 2 columns]

# %% [markdown]
# -----

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.Summary.values,df.Score.values,random_state=1)

# %%
# fucntion to clean list of strings. It will lower the character, keeps only english characters with space and lemmatize by nltk.stem.WordNetLemmatizer.
import re 
from nltk.stem import WordNetLemmatizer
def text_clean(text):
    '''  To clean list of strings. It will lower the character, keeps only english characters with space and lemmatize by nltk.stem.WordNetLemmatizer.'''
    final_text=[]
    wl=WordNetLemmatizer()
    pattern=re.compile('[^a-z ]')
    for i in text.split():
        token= i.lower()
        token=re.sub(pattern,'',token)
        token=wl.lemmatize(token)
        final_text.append(token)
    return ' '.join(final_text)

# %%
X_train_cleaned=list(map(text_clean,X_train))

# %%
X_train_cleaned
# Out:
# ['overprices and faulty weight advertiesed',
#  'i like salty',
#  'really terrible try another flavor dont waste your money',
#  'shipping cost',
#  'overpriced',
#  'tried several similar fillyourown pod this is the best',
#  'almost good a real',
#  'disappointed',
#  'look somehere else',
#  'cranberry lover',
#  'the only bar my husband will eati wish they were organic',
#  'horrible horrible product  yuck',
#  'not for me',
#  'coffee',
#  'best price on zukes',
#  'sensible food tropical',
#  'greatest snack to keep weight off',
#  'really great tea',
#  'expired',
#  'taste like licking a charred raspberry',
#  'health risk',
#  'betty crocker is gluten free pantry',
#  'reformulated to remove all taste',
#  'deep rich chocolate and mint',
#  'a favorite',
#  'no happy',
#  'rainblo   bubble gum',
#  'ginger root beer',
#  'sign',
#  'mailed garbage',
#  'tasty  crunchy with a good balance of chocolate to cereal but a bit crumbly',
#  'tasty',
#  'appears to be adulterated with grapefruit juice',
#  'frequent problem batch of this food',
#  'coffee drinker coffee i dont think so',
#  'just like car oil',
#  'disappointing',
#  'had to throw it away',
#  'yummy',
#  'dry hot wing',
#  'trident gum excellent purchase',
#  'bleh',
#  'gooood stuff',
#  'why did the price go way up',
#  'lavazza coffee truly italian',
#  'dont buy these from amazon because the cooky will be stalesoft',
#  'i really liked this',
#  'warning high fructose corn syrup',
#  'blueberry filling',
#  'excellent hearty bread',
#  'south beach diet bar',
#  'good product',
#  'tasty   yes   worth the price    no',
#  'some like to hot hot hot',
#  'nice and lemony',
#  'buy bai',
#  'the best candy on earth',
#  'good coffee',
#  'cat love it',
#  'kcup hot cocoa',
#  'ant',
#  'hope you love coffee',
#  'taste great but is le filling',
#  'a great tea',
#  'hit the sweet spot',
#  'a long a he like it',
#  'excellent dog food',
#  'lie',
#  'kyjen jigsaw glider',
#  'crazy but it taste better',
#  'these noodle are horrible ',
#  'great product',
#  'cant tell this chocolate is sugarfree',
#  'contains mg of chlorogenic acida potent antioxidant',
#  'good pick me up bad taste',
#  'tantalizingly smoky delightfully piquant',
#  'price hike too much',
#  'another great bar for nut fan',
#  'excellent',
#  'a gift well received',
#  'best allpurpose hot sauce',
#  'safer moss and algae killer',
#  'beware of new ingredient',
#  'buy a different flavor',
#  'the taste wa okay but the texture wa unpleasant',
#  'better than the best homemade',
#  'who doesnt love chef boyardee',
#  'proflowers no friend to woman',
#  'best morning coffee  timothy breakfast blend',
#  'taste great and very healthy for you',
#  'almond one are better',
#  'nothing like the original',
#  'a cup of mud',
#  'could easily break a tooth',
#  'unusual earl grey but not berrylike',
#  'i love this stuff',
#  'chinese takeout without the takeout',
#  'nasty',
#  'lacking product description',
#  'smoked paprika tin',
#  'delicious',
#  'not worth it bad concept',
#  'best coconut water around',
#  'restless leg',
#  'wonderful taste',
#  'taste good and is healthy',
#  'not for my kitten',
#  'healthy treat for the kid',
#  'love love love',
#  'no gourmet here',
#  'hain organic sugar',
#  'best thing since sliced bread',
#  'awefull',
#  'worst tea ive even had and cant return',
#  'bull part',
#  'great blend of flavor',
#  'this is great quality tea',
#  'happy owner',
#  'consistent good flavor my favorite',
#  'only use if you have no other choice',
#  'applesauce a go',
#  'taste like old sock',
#  'do not buy  terrible',
#  'very cherry',
#  'missing coffee',
#  'too much of a good thing',
#  'no longer a advertised',
#  'awesome tea',
#  'way better brand available',
#  'doesnt taste like taco bell',
#  'the cat love them so thats a plus',
#  'expired',
#  'delicous snack for picky kid',
#  'for people new to white tea',
#  'almost expired',
#  'insufficient blender',
#  'yuck',
#  'awesome but pricey',
#  'great alternative for a sweet snack',
#  'sugarless breath mint',
#  'un cafe nome desir',
#  'danger for anyone with high blood pressure',
#  'awesome chicken curry',
#  'vigo jasmine rice',
#  'one of the best mild kcups made',
#  'better than cheerio',
#  ' pure garbage ',
#  'too sweet',
#  'expresso coffee',
#  'bitter green tea',
#  'really good coffee',
#  'sparkling juice that beat ordinary soda    hand down',
#  'mustve been old',
#  'what happened',
#  'top three dog treat i have ever used',
#  'not what i wa expecting',
#  'excellent training treat',
#  'very good',
#  'great cous cous',
#  'very weak coffee with the hamilton beach brewer',
#  'best coffee candy ever',
#  'disappointed sad or displeased because someone or something ha failed to fulfill one hope or expectation',
#  'outragious price',
#  'just want one bottle and dont have time to head to china town',
#  'sweet tooth satisfied',
#  'great product  great price',
#  'excellent erin baker cooky',
#  'good if your cat will actually eat it',
#  'drain cleaner',
#  'too medicinal',
#  'favorite of our pup',
#  'good for excessive flatulence',
#  'theyre g r e a t',
#  'this soap smell terrible',
#  'best coffee',
#  'tasty bar but small nearly expired  contain unhealthy ingredient',
#  'im wild for this wild raspberry tea',
#  'great chip',
#  'coconut oil',
#  'dogswell happy hip for dog beef liver',
#  'will live without this item',
#  'doe not smell or taste like any coffee ive had in honduras',
#  'a step above a rice cake',
#  'meh',
#  'very disappointed',
#  'doe not taste good',
#  'quick  easy',
#  'so happy i found these',
#  'the recipe on the box is the only one you need',
#  'such an average craving',
#  'buyer beware',
#  'great product',
#  'love these cooky',
#  'flavorless',
#  'it got me through christmas',
#  'now thats quality',
#  'pirate booty',
#  'no effect for me',
#  'brings back memory',
#  'one star for the very weird taste important to know because it expensive',
#  'taste good but amount of packaging is ridiculous for a nature conscious company',
#  'inferior quality matcha',
#  'delicious but expensive',
#  'rip off',
#  'terrible',
#  'filler food is empty leaf your cat always needing more',
#  'filler food is empty leaf your cat always needing more',
#  'bad price',
#  'too big',
#  'very good quality',
#  'perfect substitute for egg noodle',
#  'oaty le sweet healthy tasting graham cracker adequate',
#  'nutritious and a good breakfast meal',
#  'taste fresh',
#  'broken to bit',
#  'yummy and huge',
#  'make sure you know what youre buying',
#  'do not buy',
#  'sandy texture',
#  'mine wa moldy',
#  'poor coffee  nothing to do with nantucket named wrong',
#  'great salt',
#  'healthy punch review',
#  'a loyal wolfgang puck customer',
#  'traveled a long waywell done',
#  'cocoyummy',
#  'item i ordered arrived a a totally different brand',
#  'taste like rubber',
#  'great deal on the most expensive spice',
#  'this doesnt make sense',
#  'yuk',
#  'not bad',
#  'not the real deal',
#  'a true miracle for my  year old son',
#  'disappointing',
#  'great tea great price',
#  'doe exactly what i needed it to do',
#  'what happened to the raos recipe',
#  'delicious',
#  'horrible',
#  'great for giving pill',
#  'no need to bake',
#  'garbage in a vacuum packet',
#  'lt blender from ocoee winery',
#  'gross and not a advertised',
#  'gotta love gerber',
#  'tasty but not healthy for kid with g of sugar',
#  'great space saver',
#  'this is a coffee lover coffee',
#  'if only my dog didnt love them so much',
#  'weak brew',
#  'best cracker ever',
#  'tea taste like perfume',
#  'bitter and tastless',
#  'costly hypoallergenic diet',
#  'expiry',
#  'not much taste but that make it a versatile food',
#  'my dog do not like the flavor',
#  'best i still read the label because i dont believe how healthy',
#  'calm yes but at what price',
#  'i clicked like',
#  'waste of money',
#  'dont serve to a friend',
#  'cant find it anywhere else  ',
#  'waste of money',
#  'love peanut butter but hate the fat',
#  'yum',
#  'one of the best dog food you can buy for the price',
#  'my dog didnt like them',
#  'not the truffle you want',
#  'wow i cant believe how expensive a bag of corn is',
#  'healthy cooking with coconut oil',
#  'miracle fruit tablet',
#  'bad coffee',
#  'awsome cappuccino',
#  'extremely high quality cat food at affordable price',
#  'not the same tea',
#  'holy grail of cereal',
#  'april   wa only now is  for  pack',
#  'horrible packaging',
#  'my cat love it',
#  'deelish',
#  'cat love it',
#  'great for pie crust  already in crumb',
#  'no good',
#  'great',
#  'doesnt work',
#  'never again',
#  'dont buy unless you like the taste of cardboard',
#  'too sweet',
#  'is it safe',
#  'may not be suitable for anyone with corn allergy',
#  'one of the best thousand island dressing',
#  'i love lavender',
#  'not pure matcha green tea',
#  'cat love it',
#  'bewarenot dop certified',
#  'great rice cereal',
#  'not a good a orthene',
#  'perfect for those with a sweet tooth',
#  'amazing espresso',
#  'best canned food ever',
#  'not  chicken  contains wheat and salt',
#  'meh',
#  'garlic powder',
#  'no it doe not taste like chicken',
#  'best i tried so far',
#  'very little meat bad ingredient',
#  'smooth subtle lemony note',
#  'rather tastless',
#  'love it but ',
#  'use tvp instead of boca or morningstar crumbles',
#  'help a lot',
#  'completely agree with chocolate water ewwww',
#  'terrible',
#  'omg foul foul foul',
#  'like a smore minus the marshmellow',
#  'the modern slim jim is a far cry from the original',
#  'earthy and comforting',
#  'not unique',
#  'buyer beware this is the real deal',
#  'waste of money',
#  'great snack',
#  'bread consistancy',
#  'revue of orville redenbacher natural light popcorn',
#  'too gummy',
#  'i used to love caribou coffee',
#  'dingo',
#  'not for me',
#  'horrid ingredient',
#  'weird texture taste good',
#  'vet warning do not buy',
#  'best macadamia nut ever',
#  'cant buy this at my safeway anymore',
#  ' sodium',
#  'amazing',
#  'good food',
#  'doesnt taste great',
#  'great gluten free product',
#  'beware  made in china',
#  'a great coffee at a great price',
#  'price keep going up not worth it',
#  'i love it',
#  'mmmmmchili dog mustard',
#  'great gum  finally',
#  'best coffee maker nothing really compare',
#  'love them but wish they had a  pack instead of a ',
#  'not bad at all',
#  'you get what you pay for',
#  'dont bother',
#  'dont waste your money',
#  'taste like licorice ',
#  'good product',
#  'you can put lipstick on a pig',
#  'dr d',
#  'too dark for my taste',
#  'good strong black tea',
#  'very good conditioner',
#  'not ground',
#  'celiac cook',
#  'love that olive oil soap',
#  'warning not organic anymore',
#  'great tasting and smelling tea ',
#  'good but had too many fatty piece',
#  'tasty orange soda  zero cal  and allnatural',
#  'tully decaf french roast',
#  'this is not edible',
#  'the best instant coffee',
#  'really good tea',
#  'pilling a cat is made easy by pill pocket',
#  'cat that never vomited ha been vomiting daily since formula change',
#  'le candy inside',
#  'good coffee  great company',
#  'dont buy it  dreadful',
#  'just plain bad',
#  'we love annies bunny graham',
#  'love the mustard and glad i got it through this company',
#  'not a substitute for rice krispies unfortunately',
#  'dont like the taste',
#  'absolute big time disappointing',
#  'this is not premium quality tea',
#  'brets blend tea',
#  'pecan pie larabar',
#  'bad packaging',
#  'disapointed',
#  'good cracker',
#  'delicious per the dog',
#  'taste awful',
#  'hard cherry',
#  'great for baking with',
#  'plum organic just peach',
#  'favorite treat by far',
#  'i found it too watery',
#  'great in chicken piccata and other recipe',
#  'finally a treat both you and your dog can enjoy',
#  'did not taste like the one we bought in costco',
#  'not worth the money',
#  'tested ph  ',
#  'delicious coffee',
#  'excellent',
#  'a noncompetitive price',
#  'this product is marketed lowsodium  but look at label',
#  'not to my taste bad for my teeth',
#  'horrible product',
#  'it always eight o clock at my house',
#  'love this  it our main gf breakfast option',
#  'very disappointed in the flavor',
#  'great flavor',
#  'love it',
#  'rotten when i received',
#  'oxymoron amish country  hydrogenated canola oil',
#  'these are large the cat size is smaller and ha more',
#  'made these yesterday',
#  'best hot chocolate ever',
#  'not very good',
#  'stale toffeeugh',
#  'horrible',
#  'finally a great substitute for noodle and pasta and here the calorie info',
#  'coffe mate',
#  'hardtofind item',
#  'almost a good a mine',
#  'great protein mix',
#  'buyer beware',
#  'stash darjeeling tea',
#  'splenda granulated',
#  'passable',
#  'work for me',
#  'brownieee scumbags sent me  capsule',
#  'it texas good',
#  'yummy and healthy',
#  'it doe have the low acid going for it',
#  'never again',
#  'the best kcup',
#  'frustrating',
#  'waaaay over priced',
#  'popcorn maker popcorn',
#  'excellent value',
#  'cheated me',
#  'namaste food gluten free vanilla cake mix',
#  'ok',
#  'short lived and heat kill',
#  'this stuff is amazing',
#  'taste like lawn clipping',
#  'best cooky ever',
#  'poor quality',
#  'dog love it',
#  'didnt really like it',
#  'green  black maya is gold',
#  'believe the one star review  taste like a cherry pipe',
#  'molasses oz',
#  'pearl quinoa',
#  'moldy',
#  'oder wa received in one piece',
#  'worst flavor coffee ever',
#  'too expensive',
#  'sugar shock',
#  'awful awful awful',
#  'davidsons tea bulk',
#  'best k cup',
#  'yummy',
#  'these bar are yummy',
#  'good but nothing like minestrone a we know it',
#  'purchased for myself  so i can be brutally honest',
#  'defective',
#  'great tuna fast shipment',
#  'excellent chip',
#  'great coffee but please stop smoking and put some instruction on the box',
#  'great cracker',
#  'it coffee in a can',
#  'not just for oriental menues',
#  'a great',
#  'not a advertised',
#  'not a good a the others',
#  'stash pomegranet raspberry green tea',
#  'these are the best sour gummies',
#  'oooooh chocolate',
#  'a tang that pack a punch',
#  'you cant go wrong with a quality product from a dedicated seller',
#  'taste old not like store bought',
#  'small fireball  ugh',
#  'panettone for a crowd',
#  'not for me',
#  'good for those who like their coffee le bold',
#  'a pleasing cup of coffee',
#  'free sample',
#  'folgers french vanillathe best flavor going',
#  'not ear  only small strip',
#  'nutrisoda what have you done',
#  'cough medicine',
#  'pond water would taste better',
#  'liquorice mmmm liquorice',
#  'beeman gum',
#  'bbq pop chip are amazing',
#  'good tea excellent price',
#  'not that good',
#  'chemical in a bag',
#  'used once wont finish the bottle but it might just be me',
#  'high quality and delicious snack',
#  'dont be fooled by the  star rating',
#  'delicious',
#  'so thats why they call it holy basil',
#  'new formula isnt nearly a good a the old',
#  'in a word',
#  'taste funky and sour',
#  'yum',
#  'horrible flavor',
#  'misleading',
#  'good but not for young kid',
#  'awesome product',
#  'the item contains msg',
#  'i havent received it yet',
#  'yum',
#  'soooo yummy',
#  'rewrapped oozing cheese',
#  'great tasting pudding',
#  'not so good',
#  'quick mix',
#  'these are wonderful topping',
#  'great with yogurt',
#  'disappointed',
#  'quick easy  delicious',
#  'terrible cat food',
#  'fail',
#  'delish',
#  'doggy treat',
#  'our least favorite',
#  'never gotten my order',
#  'best graham cracker ever',
#  'not recommended',
#  'good solid product  worth eating somewhat spicy',
#  'work but too weak',
#  'good value and fast shipping',
#  'great',
#  'too expensive',
#  'no more baristas and  dollar latte for me',
#  'briny somewhat anxiety producing pas',
#  'nice modern lid',
#  'unwanted ingredient',
#  'these are great',
#  'the name say it all',
#  'i love this rice',
#  'doesnt work',
#  'apple are not properly cored',
#  'good value',
#  'no saving',
#  'not so fresh',
#  'taste much richer',
#  'great tea',
#  'handy protein snack',
#  'bring back the butter',
#  'not worth the money',
#  'flax seed are so good for you',
#  'watery and flavorless',
#  'bisquick gf mix',
#  'our  dog love it',
#  'tasty  spirited',
#  'no different looking than regular stick of gum',
#  'great cooky and good for you',
#  'misleading description',
#  'pasturized',
#  'worthless',
#  'awful',
#  'review of unique cup designnot the coffee inside it',
#  'best peach candy ever',
#  'great meal starter',
#  'one of the worst gf product i have found to date',
#  'this is not a gluten free product',
#  'no orange taste and not spicy',
#  'ruined the christmas surprise',
#  'if you like campbell pepper pot soup then dont buy this',
#  'just what i wa looking for',
#  'good',
#  'decaf you wouldnt know',
#  'my dog seems to like it but   ',
#  'k cup assortment',
#  'great saving',
#  'low calorie no fat low sodium snack food',
#  'what a deal',
#  'healthy food can taste good',
#  'amazing jerk seasoning',
#  'delish',
#  'clorets',
#  'not worth it',
#  'not a fan ',
#  'too much turmeric for chicken soup',
#  'now basted not wrapped',
#  'horrifying',
#  'i cant see that it work',
#  'best italian dressing you can buy',
#  'the most tasteless earl grey ever',
#  'oooooooooooooooooh baby baybee',
#  'mmmmm mmmm good',
#  'love it',
#  'good ingredient good effect',
#  'what a disappointment',
#  'just right when mixed half and half with cherrios',
#  'meh',
#  'my favorite oil',
#  'my dog accepted it but they crapped x more',
#  'not the regular size gumballs that you see in the store',
#  'great price',
#  'good substitute for some cream soup',
#  'got diarrhea',
#  'horrible  do not buy',
#  'nice shampoo nice price',
#  'pretty good snack',
#  'disgustingdont be fooled by the packaging',
#  'blast from the past',
#  'disappointing',
#  'milkbone dog treat  digest of poultry by product',
#  'extremely foul taste',
#  'best peanut butter value  bar none',
#  'the best chipsperiod',
#  'great mild flavor',
#  'better than dessicated liver or pepperoni',
#  'might have taste but that also come from artificial flavoring',
#  'so good',
#  'we all love it',
#  'love it a favorite of mine',
#  'a fan of the product but not the price',
#  'spicy and delicious',
#  'flatus',
#  'greenies joint care',
#  'great for a fat dog with a sensitive stomach',
#  'too bad they dont list the ingredient',
#  'over a dollar for a kcup',
#  'the box would have tasted better',
#  'smell like french toast with maple syrup',
#  'poor labeling make for a ripoff',
#  'licorice',
#  'too sweet',
#  'no peppermint flavor',
#  'tasty',
#  'awesome snack',
#  'best mass marketed dried meat product on earth',
#  'incorrect description',
#  'my dog adores these delicious treat',
#  'an unfortunate pairing',
#  'container top problem',
#  'great stuff',
#  'excellent flavorful coffee',
#  'have to get use to the taste ',
#  'dutch treet',
#  'useless',
#  'heart beware',
#  'awful',
#  'almost expired',
#  'decent coffee horrible packaging',
#  'syrup',
#  'subtle mild enjoyable green tea',
#  'terrible food pod',
#  'msg reaction',
#  'great product and price',
#  'how to use',
#  'winter wellness',
#  'i love mound',
#  'horrible do not buy',
#  'amazingly decadent',
#  'awful smell',
#  'gluten free gourmet snack',
#  'great tasting tea',
#  'pickapeppa is so good',
#  'sport tea is great',
#  'weird taste',
#  'im really dissapointed',
#  'decent variety',
#  'weak tea',
#  'really',
#  'what no sale slip',
#  'toxic goji',
#  'love it',
#  'terrible',
#  'good stuff',
#  'you have to use double the dose of this',
#  'will buy no other',
#  'great quality product',
#  'terrible smell like dog food',
#  'beware',
#  'missing item',
#  'bring back the old recipe',
#  'my baby love it',
#  'doe what it say',
#  'worst beet ive ever eaten',
#  'what a wonderful cup of tea',
#  'great breakfast bar',
#  'much anticipated great product',
#  'arf arf ',
#  'work with the keurig machine too',
#  'closest thing to a frango yet',
#  'flavored coffee',
#  'wonderful tea',
#  'not very creamy or chivey',
#  'even my very fussy eater like this',
#  'lightly sweetened green iced tea powder',
#  'not a reliable deilvery system',
#  'ehh',
#  'very poor quality little real meat',
#  'waggin train linked to over  death',
#  'caused my  year old cat to have diarrhea for first time in his life',
#  'burn off the muffin top',
#  'minty fresh breath',
#  'great lean snack  ostrich',
#  'unhealthy first  ingredient',
#  'city steam not much steam in this brew',
#  'lipton know tea',
#  'it wa only the rancid smell',
#  'yummy but overpriced',
#  'soft chewable yummy treat for your agingarthritic dog',
#  'spoiled case',
#  'unable to use a shipped do not grind properly in my equipment',
#  'crown prince anchoviesnot good',
#  'dog food masquerading a cat food',
#  'great value',
#  'umame at last',
#  'love it',
#  'noodle',
#  'the best ive found',
#  'my dog love them',
#  'so amazingly delicious',
#  'my dog loooove these',
#  'absolutely love these',
#  'popcorn anyone',
#  'absotively posilutely delicious',
#  'did you not receive complete kit',
#  'couldnt be happier',
#  'the best bean ever higher in fiber and ready in min',
#  'some like it hot gift basket wa a hit ',
#  'the only tea i drink',
#  'will not buy again',
#  'extremly salty',
#  'taste like plastic',
#  'product change',
#  'love this stuff',
#  'y so minty',
#  'great cracker',
#  'do not order this product',
#  'do not buy this unless you like antique candy',
#  'horrible smell of this product',
#  'horrible',
#  'good but watch for pit',
#  'awsome movie awsome d box cover',
#  'i dont give a hoot about van houtte',
#  'g carb per serving',
#  'yummy cooky',
#  'best veg jerky',
#  'loving the lemon',
#  'fiesta brisket rub',
#  'worst tasting stuff',
#  'dissapointing',
#  'sickening filler ingredient high price',
#  'product in great condition',
#  'poor taste',
#  'cat couldnt eat it',
#  'wrong item sent to me',
#  'good tasting tea great value',
#  'do you like water',
#  'good snacking',
#  'good deal',
#  'too expensive at amazon',
#  'arrived with melted center',
#  'not so great',
#  'soft but dry and crumbly',
#  'absolute rip off',
#  'well never go back to baked',
#  'steaz local energy is horrible',
#  'still not here',
#  'disappointed',
#  'my dog like these soft treat better than the traditional zukes treat',
#  'too big for a mug not big enough flavor',
#  'wonderful a miracle lol',
#  'freshness ',
#  'dead on arrival caught on fire',
#  'charlies choice',
#  'do the math',
#  'husband favorite candy bar',
#  'best treat ever',
#  'didnt last a day',
#  'worst beef jerky ive ever had',
#  'strange coconut aroma',
#  'contains yeast extract',
#  'missed the mark',
#  'ill take the orchid please',
#  'great breakfast coffee',
#  'for adult or overstimulated kid',
#  'not for senseo',
#  'yum',
#  'blueberry coffee oh yes maam',
#  'very disapointed',
#  'good product good service',
#  'favorite granola',
#  'too small',
#  'not so black',
#  'good result',
#  'excellent coffee mild and flavorful',
#  'not a pictured',
#  'havent used in recipe yet but  out of  can were badly dented and it wa in a case',
#  'misleading name',
#  'chip easily',
#  'i miss gloria jean cappuccino',
#  'excellent product',
#  'perfect mayo substitute',
#  'disgusting',
#  'our cat no longer will touch any of it',
#  'great dog food at a great price',
#  'great cerealhealthy and tasty',
#  'sometimes really bad',
#  'saeco vienna plus a worthy successor to yearold vienna deluxe',
#  'warning  not safe',
#  'barfy',
#  'it salt',
#  'apple crisp are the best',
#  'great snack for on the go',
#  'ive purchased this several time because it great',
#  'excellent cereal at a good price',
#  'excellent nutrition picky eater like it',
#  'overrated',
#  'great jerky',
#  'more than a bite',
#  'my cat meow at me every morning',
#  'coffee',
#  'caution',
#  'bait and switch',
#  'yum ',
#  'love it',
#  'not the same a the canned version',
#  'it my new best friend',
#  'by far the best  no after taste nor indigestion',
#  'wa not fresh  i bought six pack open the first one and wa thnking it wa just this one and all the six pack wa humis and',
#  'just not a fan',
#  'burn sensitive skin',
#  'great tasting coffee',
#  'my favorite kcups',
#  'greenies are the best',
#  'i wa suppose to have it come once a month',
#  'poor customer service',
#  'saturated fat nightmare',
#  'not a very good batch',
#  'not what i expected and not in a good way',
#  'worthy of a subscriptionyes',
#  'best',
#  'spoiled and not returnable',
#  'horrible taste',
#  'poorly packaged',
#  'love it',
#  'not even deserving of a star',
#  'just what my dog needed',
#  'blah',
#  'unhappy hip supplied by amazon',
#  'disappointed',
#  'love it',
#  'great snack for people on the go',
#  'not working for my dog',
#  'delectably delicious',
#  'from someone who grew up on coconut milkwater',
#  'is this price right',
#  'seattle best level ',
#  'high risk dont order can',
#  'artificially sweetened and minimal coffee taste',
#  'vegetable base',
#  'no onion flavor',
#  'sweet treat',
#  'carrie',
#  'questionable ingredient',
#  'warning may contain lead',
#  'great product some squishing in shipping',
#  'way too weak',
#  'good tasting and healthy',
#  'healthier alternative for chip fix',
#  'healthy oatsgreat taste',
#  'not authentic but still nice',
#  'disappointed',
#  'some of the candy is stale',
#  'interesting herbal mix',
#  'very good tea',
#  'great product horrible price',
#  'give it a try',
#  'hard and dry cooky',
#  'the best stock in the world',
#  'disappointed',
#  'fizzies drink tablet',
#  'bad beef',
#  'big disappointment from a favorite brand',
#  'i like this product',
#  'great product',
#  'filler food is empty leaf your cat always needing more',
#  'stinky tea',
#  'dog seems happy',
#  'meh',
#  'gross',
#  'gimme more',
#  'too dry  repackage',
#  'very bland',
#  'disgusting product',
#  'this organic cherry vanilla granola taste great',
#  'small size excessive shipping',
#  'my cup run over',
#  'usda doe not certify product',
#  'delicious',
#  'bobby favorite ',
#  'some lowcaloire sin',
#  'stinky',
#  'had better',
#  'i must have done something wrong',
#  'amazing',
#  'ellas isnt half bad',
#  'best ever veggie jerky',
#  'yuck',
#  'not a challenge',
#  'taste like sweaty gym sock',
#  'a touch of elegance',
#  'coffee only better',
#  'poorly marketed bad labeling',
#  'these cooky are  in my supermarket',
#  'love this tangy tea',
#  'what a shame',
#  'my cat love these treat',
#  'kettle chip',
#  'baby food product made in mainland china no thanks',
#  'no real food for dog',
#  'taste like sweaty gym sock',
#  'such a deal',
#  'bht is bad news',
#  'didnt work',
#  'good stuff',
#  'oreo always win',
#  'get out of the way',
#  'crowd pleaser',
#  'bewarenot a oz jug',
#  'confused about title of product',
#  'best peanut brittle ive tasted',
#  'website data',
#  'good in a pinch',
#  'raisin branuhwhere are the raisin',
#  'a good decafe',
#  'liver treat',
#  'too sweet and doe not quench thirst',
#  'made in china',
#  'changed the ingredient to now include meat product zero star',
#  'cat loved it buttheir hair started to fall out',
#  'le meat in new formula',
#  'it no bariani but',
#  'great last minute gift idea',
#  'nasty',
#  'wheres the nut',
#  'bewarethe formula ha changed',
#  'product taste wa fine shipping poor',
#  'great treat',
#  'chocolate raspberry truffle coffee',
#  'wish it tasted good',
#  'it ha trans fat',
#  'hot yeah right',
#  'great product',
#  'incredible scone',
#  'missing one cup',
#  'dont waste money',
#  'flavordoh ',
#  'dangerous to cat',
#  'disgusting',
#  'good taste  poor packaging',
#  'lavazza is a poor choice',
#  'i like this product',
#  'banana nut snackin cake',
#  'tasty but disappointed',
#  'chip rancid despite december  exp date',
#  'bravo lobster meat treat',
#  'toxic hexane used in extraction of dha',
#  'not the best taste and left me jittery',
#  'just ok',
#  'do not purchasereally disgusting',
#  'not feeling well after eating',
#  'splenda in every flavortastes horrible',
#  'beef tendon',
#  'great taste hearty snack',
#  'stale',
#  'great product',
#  'not impressed',
#  'in a can',
#  'good product bad packeting',
#  'favorite candy bar  cheapest at sam club',
#  'very disappointing',
#  'guilt free nibble',
#  'wonderful dog food',
#  'a great snack',
#  'raw honey what the heck doe that meam',
#  'best mint',
#  'dear reesesticks crispy wafer why are you so yummy',
#  'yummy',
#  'delicious',
#  'too salty',
#  'lacking in flavor',
#  'good for dog coat',
#  'judy',
#  'love it',
#  'great northern popcorn',
#  'healthy bar',
#  'kind of a miss',
#  'too gritty',
#  'great coffee',
#  'they smell horrible',
#  'very artificial',
#  ...]

# %%
# feature extraction
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
sw=list(ENGLISH_STOP_WORDS)
sw.remove('not')
sw.remove('no')
sw.remove('cant')
sw.remove('couldnt')
sw.remove('should')
sw.remove('why')
sw.remove('under')
sw.remove('nor')
sw.remove('very')
sw.remove('well')
sw.remove('more')
sw.remove('off')
sw.remove('but')
sw.remove('found')
sw.remove('top')

cv=CountVectorizer(lowercase=True,stop_words=sw)
X_train_final=cv.fit_transform(X_train_cleaned)  # cv.fit_transform() returns an sparce matrix and we need simple matrix

# %%
X_train_final.shape
# Out:
# (1500, 1493)

# %% [markdown]
# ____

# %%
# feature selection wih SequentialFeatureSelector with model=Multinomial to select best features
# if try block does not work this cell can take approx 25 mint to get the output. meaning, if the features not found in local machine (selected before) 
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.naive_bayes import MultinomialNB
# to save/load sparce matrix in the local machine
from scipy.sparse import save_npz,load_npz
# to save an object
import pickle

try:
    with open('sfs.pickle', 'rb') as obj:
        sfs=pickle.load(obj)
    X_train_final=load_npz('X_train_final.npz')
except:
    model = MultinomialNB() 
    sfs=SequentialFeatureSelector(model, n_features_to_select=1400, cv = 5, direction='backward')
    X_train_final = sfs.fit_transform(X_train_final,y_train)
    with open('sfs.pickle','wb') as obj:
        pickle.dump(sfs,obj)
    save_npz('X_train_final.npz', X_train_final)

# %%
X_train_final.shape
# Out:
# (1500, 1400)

# %% [markdown]
# -----

# %%
# model building, and scoring
from sklearn.naive_bayes import MultinomialNB, GaussianNB,BernoulliNB

model=MultinomialNB()   # best suitable with CountVectorizer
model.fit(X_train_final,y_train)
model.score(X_train_final,y_train)
# Out:
# 0.944

# %%
# confusion matrix of training data
from sklearn.metrics import confusion_matrix
pred_train=model.predict(X_train_final)
cmatrix=confusion_matrix(y_train,pred_train)
cmatrix
# Out:
# array([[691,  54],
#        [ 30, 725]], dtype=int64)

# %%
# performance on testing data
X_test_cleaned=list(map(text_clean,X_test))
X_test_final=cv.transform(X_test_cleaned)
X_test_final=sfs.transform(X_test_final)
pred_test=model.predict(X_test_final)
model.score(X_test_final,y_test)
# Out:
# 0.782

# %% [markdown]
# ----

# %%
# singale sample test
sample=['The dinner good']
s_cleaned=list(map(text_clean,sample))
s_final=cv.transform(s_cleaned)
s_final=sfs.transform(s_final)
model.predict(s_final)
# Out:
# array([1], dtype=int64)

# %% [markdown]
# 👍 The result is correct as the sample provided have positive sentiment.

# %% [markdown]
# #### Testing with another dataset

# %%
# it is a balanced and without null values dataset
df_test=pd.read_csv('datasets/Restaurant_Reviews.txt',sep='\t')
df_test
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %%
# scoring
X_test_cleaned=list(map(text_clean,df_test.Review))
X_final=cv.transform(X_test_cleaned)
X_final=sfs.transform(X_final)
model.score(X_final,df_test.Liked)
# Out:
# 0.744

# %%
# confusion matrix
pred_test=model.predict(X_final)
matrics=confusion_matrix(df_test.Liked,pred_test)

# %%
matrics
# Out:
# array([[408,  92],
#        [164, 336]], dtype=int64)

# %% [markdown]
# ----

# %% [markdown]
# 😒 The performance of the model is not much good on unseen data but on seen data, it can be considerable. Performance of this model should be improved.
#
# ✔
